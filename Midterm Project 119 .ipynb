# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import random
plt.style.use('fivethirtyeight')

# %%
df2015 = pd.read_csv(r'2015.csv', decimal = ',')
df2016 = pd.read_csv(r'2016.csv',decimal = ',')
df2017 = pd.read_csv(r'2017.csv',decimal = ',')
df2018 = pd.read_csv(r'2018.csv',decimal = ',')
df2019 = pd.read_csv(r'2019.csv',decimal = ',')
df2020 = pd.read_csv(r'2020.csv',decimal = ',')
df2021 = pd.read_csv(r'2021.csv',decimal = ',')
df2022 = pd.read_csv(r'2022.csv',decimal = ',')

# %%
df2015.shape, df2016.shape, df2017.shape, df2018.shape, df2019.shape, df2020.shape, df2021.shape, df2022.shape
# Out:
# ((158, 12),
#  (157, 13),
#  (155, 12),
#  (156, 9),
#  (156, 9),
#  (153, 20),
#  (149, 20),
#  (147, 12))

# %%
#adding years
yrs = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
dfs = [df2015, df2016, df2017, df2018, df2019, df2020, df2021, df2022]
for i in range(0,8):
    dfs[i]['Year'] = yrs[i]

# %%
#Common column names
df2015.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
common_cols = ['Happiness Rank', 'Country', 'Region', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)','Health (Life Expectancy)','Freedom', 'Trust (Government Corruption)','Generosity','Year']

# %%
df2015 = df2015.rename(columns={'Family':'Family (Social Support)'})

# %%
df2015.head()
# Out:
#        Country          Region  Happiness Rank Happiness Score Standard Error  \
# 0  Switzerland  Western Europe               1           7.587        0.03411
# 1      Iceland  Western Europe               2           7.561        0.04884
# 2      Denmark  Western Europe               3           7.527        0.03328
# 3       Norway  Western Europe               4           7.522         0.0388
# 4       Canada   North America               5           7.427        0.03553
#
#   Economy (GDP per Capita) Family (Social Support) Health (Life Expectancy)  \
# 0                  1.39651                 1.34951                  0.94143
# 1                  1.30232                 1.40223                  0.94784
# 2                  1.32548                 1.36058                  0.87464
# 3                    1.459                 1.33095                  0.88521
# 4                  1.32629                 1.32261                  0.90563
#
#    Freedom Trust (Government Corruption) Generosity Dystopia Residual  Year
# 0  0.66557                       0.41978    0.29678           2.51738  2015
# 1  0.62877                       0.14145     0.4363           2.70201  2015
# 2  0.64938                       0.48357    0.34139           2.49204  2015
# 3  0.66973                       0.36503    0.34699           2.46531  2015
# 4  0.63297                       0.32957    0.45811           2.45176  2015

# %% [markdown]
# # 2016

# %%
df2016.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Lower Confidence Interval',
#  'Upper Confidence Interval',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual',
#  'Year']

# %%
df2016 = df2016.rename(columns={'Family':'Family (Social Support)'})
df2016.head()
# Out:
#        Country          Region  Happiness Rank Happiness Score  \
# 0      Denmark  Western Europe               1           7.526
# 1  Switzerland  Western Europe               2           7.509
# 2      Iceland  Western Europe               3           7.501
# 3       Norway  Western Europe               4           7.498
# 4      Finland  Western Europe               5           7.413
#
#   Lower Confidence Interval Upper Confidence Interval  \
# 0                      7.46                     7.592
# 1                     7.428                      7.59
# 2                     7.333                     7.669
# 3                     7.421                     7.575
# 4                     7.351                     7.475
#
#   Economy (GDP per Capita) Family (Social Support) Health (Life Expectancy)  \
# 0                  1.44178                 1.16374                  0.79504
# 1                  1.52733                 1.14524                  0.86303
# 2                  1.42666                 1.18326                  0.86733
# 3                  1.57744                  1.1269                  0.79579
# 4                  1.40598                 1.13464                  0.81091
#
#    Freedom Trust (Government Corruption) Generosity Dystopia Residual  Year
# 0  0.57941                       0.44453    0.36171           2.73939  2016
# 1  0.58557                       0.41203    0.28083           2.69463  2016
# 2  0.56624                       0.14975    0.47678           2.83137  2016
# 3  0.59609                       0.35776    0.37895           2.66465  2016
# 4  0.57104                       0.41004    0.25492           2.82596  2016

# %% [markdown]
# # 2017

# %%
df2017.columns.to_list()
# Out:
# ['Country',
#  'Happiness.Rank',
#  'Happiness.Score',
#  'Whisker.high',
#  'Whisker.low',
#  'Economy..GDP.per.Capita.',
#  'Family',
#  'Health..Life.Expectancy.',
#  'Freedom',
#  'Generosity',
#  'Trust..Government.Corruption.',
#  'Dystopia.Residual',
#  'Year']

# %%
df2017 = df2017.rename(columns={'Happiness.Rank':'Happiness Rank', 'Happiness.Score':'Happiness Score','Economy..GDP.per.Capita.':'Economy (GDP per Capita)','Family':'Family (Social Support)','Health..Life.Expectancy.':'Health (Life Expectancy)','Trust..Government.Corruption.':'Trust (Government Corruption)'})

# %%
df2017 = df2017.merge(df2015[["Country","Region"]], on="Country", how="left")
df2017["Region"] = df2017["Region"].fillna('-')

# %% [markdown]
# # 2018

# %%
df2018.columns.to_list()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Year']

# %%
df2018 = df2018.rename(columns={'Overall rank':'Happiness Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)','Social support':'Family (Social Support)','Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices':'Freedom','Perceptions of corruption':'Trust (Government Corruption)'})

# %%
df2018 = df2018.merge(df2015[["Country","Region"]], on="Country", how="left")
df2018["Region"] = df2018["Region"].fillna('-')

# %%
df2018.head()
# Out:
#    Happiness Rank      Country Happiness Score Economy (GDP per Capita)  \
# 0               1      Finland           7.632                    1.305
# 1               2       Norway           7.594                    1.456
# 2               3      Denmark           7.555                    1.351
# 3               4      Iceland           7.495                    1.343
# 4               5  Switzerland           7.487                    1.420
#
#   Family (Social Support) Health (Life Expectancy) Freedom Generosity  \
# 0                   1.592                    0.874   0.681      0.202
# 1                   1.582                    0.861   0.686      0.286
# 2                   1.590                    0.868   0.683      0.284
# 3                   1.644                    0.914   0.677      0.353
# 4                   1.549                    0.927   0.660      0.256
#
#   Trust (Government Corruption)  Year          Region
# 0                         0.393  2018  Western Europe
# 1                         0.340  2018  Western Europe
# 2                         0.408  2018  Western Europe
# 3                         0.138  2018  Western Europe
# 4                         0.357  2018  Western Europe

# %% [markdown]
# # 2019

# %%
df2019.columns.to_list()
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Year']

# %%
df2019 = df2019.rename(columns={'Overall rank':'Happiness Rank', 'Country or region':'Country', 'Score':'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)','Social support':'Family (Social Support)','Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices':'Freedom','Perceptions of corruption':'Trust (Government Corruption)'})

# %%
df2019 = df2019.merge(df2015[["Country","Region"]], on="Country", how="left")
df2019["Region"] = df2019["Region"].fillna('-')

# %% [markdown]
# # 2020

# %%
df2020 = df2020.rename(columns={'Country name':'Country','Regional indicator': 'Region','Ladder score':'Happiness Score','Explained by: Social support':'Family (Social Support)','Explained by: Healthy life expectancy':'Health (Life Expectancy)','Explained by: Freedom to make life choices':'Freedom','Explained by: Perceptions of corruption':'Trust (Government Corruption)','Explained by: Log GDP per capita':'Economy (GDP per Capita)','Explained by: Generosity':'Generosity'})

# %%
df2020['Happiness Rank'] = [i for i in range(1, len(df2020.index)+1)]

# %%
df2020 = df2020.loc[:,~df2020.columns.duplicated(keep='last')]

# %%
df2020.head()
# Out:
#        Country          Region Happiness Score Standard error of ladder score  \
# 0      Finland  Western Europe     7.808700085                    0.031156305
# 1      Denmark  Western Europe     7.645599842                    0.033492286
# 2  Switzerland  Western Europe     7.559899807                    0.035014171
# 3      Iceland  Western Europe     7.504499912                    0.059615862
# 4       Norway  Western Europe     7.487999916                    0.034837384
#
#   upperwhisker lowerwhisker Logged GDP per capita Social support  \
# 0  7.869766235  7.747633934           10.63926697    0.954329729
# 1  7.711244583  7.579955101           10.77400112    0.955990791
# 2  7.628527641  7.491271973           10.97993279    0.942846596
# 3  7.621346951  7.387652874           10.77255917    0.974669576
# 4   7.55628109  7.419718742           11.08780384    0.952486575
#
#   Healthy life expectancy Freedom to make life choices  ...  \
# 0              71.9008255                  0.949172199  ...
# 1             72.40250397                  0.951444268  ...
# 2             74.10244751                  0.921336651  ...
# 3                      73                  0.948891878  ...
# 4             73.20078278                  0.955750287  ...
#
#   Ladder score in Dystopia Economy (GDP per Capita) Family (Social Support)  \
# 0              1.972316742              1.285189509             1.499525905
# 1              1.972316742              1.326948524             1.503449202
# 2              1.972316742               1.39077425             1.472403407
# 3              1.972316742              1.326501608             1.547567487
# 4              1.972316742               1.42420733             1.495172501
#
#   Health (Life Expectancy)      Freedom   Generosity  \
# 0              0.961271405   0.66231674  0.159670442
# 1              0.979332566  0.665039897  0.242793396
# 2              1.040533185   0.62895447  0.269055754
# 3              1.000843406  0.661980748  0.362330228
# 4              1.008071899  0.670200884  0.287985086
#
#   Trust (Government Corruption) Dystopia + residual  Year Happiness Rank
# 0                   0.477857262         2.762835026  2020              1
# 1                   0.495260328         2.432740688  2020              2
# 2                   0.407945901          2.35026741  2020              3
# 3                   0.144540772         2.460688114  2020              4
# 4                   0.434100568         2.168266296  2020              5
#
# [5 rows x 21 columns]

# %% [markdown]
# #  2021

# %%
df2021.columns.to_list()
# Out:
# ['Country name',
#  'Regional indicator',
#  'Ladder score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Explained by: Log GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Dystopia + residual',
#  'Year']

# %%
df2021 = df2021.rename(columns={'Country name':'Country','Regional indicator': 'Region','Ladder score':'Happiness Score','Explained by: Social support':'Family (Social Support)','Explained by: Healthy life expectancy':'Health (Life Expectancy)','Explained by: Freedom to make life choices':'Freedom','Explained by: Perceptions of corruption':'Trust (Government Corruption)','Explained by: Log GDP per capita':'Economy (GDP per Capita)','Explained by: Generosity':'Generosity'})

# %%
df2021 = df2021.loc[:,~df2021.columns.duplicated(keep='last')]

# %%
df2021['Happiness Rank'] = [i for i in range(1, len(df2021.index)+1)]

# %%
#will merge on common columns so removing doesnt matter
df2021.head()
# Out:
#        Country          Region Happiness Score Standard error of ladder score  \
# 0      Finland  Western Europe           7.842                          0.032
# 1      Denmark  Western Europe           7.620                          0.035
# 2  Switzerland  Western Europe           7.571                          0.036
# 3      Iceland  Western Europe           7.554                          0.059
# 4  Netherlands  Western Europe           7.464                          0.027
#
#   upperwhisker lowerwhisker Logged GDP per capita Social support  \
# 0        7.904        7.780                10.775          0.954
# 1        7.687        7.552                10.933          0.954
# 2        7.643        7.500                11.117          0.942
# 3        7.670        7.438                10.878          0.983
# 4        7.518        7.410                10.932          0.942
#
#   Healthy life expectancy Freedom to make life choices  ...  \
# 0                  72.000                        0.949  ...
# 1                  72.700                        0.946  ...
# 2                  74.400                        0.919  ...
# 3                  73.000                        0.955  ...
# 4                  72.400                        0.913  ...
#
#   Ladder score in Dystopia Economy (GDP per Capita) Family (Social Support)  \
# 0                    2.430                    1.446                   1.106
# 1                    2.430                    1.502                   1.108
# 2                    2.430                    1.566                   1.079
# 3                    2.430                    1.482                   1.172
# 4                    2.430                    1.501                   1.079
#
#   Health (Life Expectancy) Freedom Generosity Trust (Government Corruption)  \
# 0                    0.741   0.691      0.124                         0.481
# 1                    0.763   0.686      0.208                         0.485
# 2                    0.816   0.653      0.204                         0.413
# 3                    0.772   0.698      0.293                         0.170
# 4                    0.753   0.647      0.302                         0.384
#
#   Dystopia + residual  Year Happiness Rank
# 0               3.253  2021              1
# 1               2.868  2021              2
# 2               2.839  2021              3
# 3               2.967  2021              4
# 4               2.798  2021              5
#
# [5 rows x 21 columns]

# %% [markdown]
# # 2022

# %%
df2022.columns.to_list()
# Out:
# ['RANK',
#  'Country',
#  'Happiness score',
#  'Whisker-high',
#  'Whisker-low',
#  'Dystopia (1.83) + residual',
#  'Explained by: GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Year']

# %%
df2022 = df2022.merge(df2015[["Country","Region"]], on="Country", how="left")
df2022["Region"] = df2022["Region"].fillna('-')

# %%
df2022 = df2022.rename(columns={'RANK':'Happiness Rank','Happiness score':'Happiness Score','Explained by: GDP per capita':'Economy (GDP per Capita)', 'Explained by: Social support':'Family (Social Support)','Explained by: Healthy life expectancy':'Health (Life Expectancy)','Explained by: Freedom to make life choices':'Freedom','Explained by: Generosity':'Generosity', 'Explained by: Perceptions of corruption':'Trust (Government Corruption)'})

# %%
df2022.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Whisker-high  Whisker-low  \
# 0               1      Finland            7.821         7.886        7.756
# 1               2      Denmark            7.636         7.710        7.563
# 2               3      Iceland            7.557         7.651        7.464
# 3               4  Switzerland            7.512         7.586        7.437
# 4               5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Economy (GDP per Capita)  \
# 0                       2.518                     1.892
# 1                       2.226                     1.953
# 2                       2.320                     1.936
# 3                       2.153                     2.026
# 4                       2.137                     1.945
#
#    Family (Social Support)  Health (Life Expectancy)  Freedom  Generosity  \
# 0                    1.258                     0.775    0.736       0.109
# 1                    1.243                     0.777    0.719       0.188
# 2                    1.320                     0.803    0.718       0.270
# 3                    1.226                     0.822    0.677       0.147
# 4                    1.206                     0.787    0.651       0.271
#
#    Trust (Government Corruption)  Year          Region
# 0                          0.534  2022  Western Europe
# 1                          0.532  2022  Western Europe
# 2                          0.191  2022  Western Europe
# 3                          0.461  2022  Western Europe
# 4                          0.419  2022  Western Europe

# %% [markdown]
# # Merged

# %%
years = [df2015[common_cols], df2016[common_cols], df2017[common_cols], df2018[common_cols], df2019[common_cols], df2020[common_cols], df2021[common_cols], df2022[common_cols]]

# %%
Merged = pd.DataFrame(columns=common_cols)

# %%
Merged = Merged.append(years)

# %%
Merged.dropna(axis='rows',inplace=True)
Merged
# Out:
#     Happiness Rank      Country                           Region  \
# 0                1  Switzerland                   Western Europe
# 1                2      Iceland                   Western Europe
# 2                3      Denmark                   Western Europe
# 3                4       Norway                   Western Europe
# 4                5       Canada                    North America
# ..             ...          ...                              ...
# 141            142    Botswana*                                -
# 142            143      Rwanda*                                -
# 143            144     Zimbabwe               Sub-Saharan Africa
# 144            145      Lebanon  Middle East and Northern Africa
# 145            146  Afghanistan                    Southern Asia
#
#     Happiness Score Economy (GDP per Capita) Family (Social Support)  \
# 0             7.587                  1.39651                 1.34951
# 1             7.561                  1.30232                 1.40223
# 2             7.527                  1.32548                 1.36058
# 3             7.522                    1.459                 1.33095
# 4             7.427                  1.32629                 1.32261
# ..              ...                      ...                     ...
# 141           3.471                    1.503                   0.815
# 142           3.268                    0.785                   0.133
# 143           2.995                    0.947                    0.69
# 144           2.955                    1.392                   0.498
# 145           2.404                    0.758                     0.0
#
#     Health (Life Expectancy)  Freedom Trust (Government Corruption)  \
# 0                    0.94143  0.66557                       0.41978
# 1                    0.94784  0.62877                       0.14145
# 2                    0.87464  0.64938                       0.48357
# 3                    0.88521  0.66973                       0.36503
# 4                    0.90563  0.63297                       0.32957
# ..                       ...      ...                           ...
# 141                     0.28    0.571                         0.102
# 142                    0.462    0.621                         0.544
# 143                     0.27    0.329                         0.105
# 144                    0.631    0.103                         0.034
# 145                    0.289      0.0                         0.005
#
#     Generosity  Year
# 0      0.29678  2015
# 1       0.4363  2015
# 2      0.34139  2015
# 3      0.34699  2015
# 4      0.45811  2015
# ..         ...   ...
# 141      0.012  2022
# 142      0.187  2022
# 143      0.106  2022
# 144      0.082  2022
# 145      0.089  2022
#
# [1229 rows x 11 columns]

# %%
#Merged['Happiness Score'] = Merged['Happiness Score'].astype(np.float)
#Merged['Freedom'] = Merged['Freedom'].astype(np.float)
Merged.iloc[:,3:14]= Merged.iloc[:,3:14].astype(np.float)
# Out:
# C:\Users\charl\AppData\Local\Temp/ipykernel_836/1979731516.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Merged.iloc[:,3:14]= Merged.iloc[:,3:14].astype(np.float)

# %%
Merged['Trust (Government Corruption)'].describe()
# Out:
# count    1229.000000
# mean        0.130756
# std         0.110818
# min         0.000000
# 25%         0.056000
# 50%         0.096000
# 75%         0.164000
# max         0.587000
# Name: Trust (Government Corruption), dtype: float64

# %%
Merged['Economy (GDP per Capita)'].describe()
# Out:
# count    1229.000000
# mean        0.975343
# std         0.434249
# min         0.000000
# 25%         0.668000
# 50%         1.012160
# 75%         1.295843
# max         2.209000
# Name: Economy (GDP per Capita), dtype: float64

# %%
a = np.where(Merged['Economy (GDP per Capita)'] == 0)
Merged.iloc[a]
# Out:
#     Happiness Rank                   Country                       Region  \
# 119            120          Congo (Kinshasa)           Sub-Saharan Africa
# 75              76                   Somalia           Sub-Saharan Africa
# 154            155  Central African Republic           Sub-Saharan Africa
# 97              98                   Somalia                            -
# 111            112                   Somalia                            -
# 139            140                   Burundi           Sub-Saharan Africa
# 139            140                   Burundi           Sub-Saharan Africa
# 107            108                 Venezuela  Latin America and Caribbean
#
#      Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 119           4.5170                       0.0                 1.001200
# 75            5.4400                       0.0                 0.336130
# 154           2.6930                       0.0                 0.000000
# 97            4.9820                       0.0                 0.712000
# 111           4.6680                       0.0                 0.698000
# 139           3.7753                       0.0                 0.403575
# 139           3.7750                       0.0                 0.062000
# 107           4.9250                       0.0                 0.968000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 119                  0.098060  0.226050                       0.076250
# 75                   0.114660  0.567780                       0.311800
# 154                  0.018773  0.270842                       0.056565
# 97                   0.115000  0.674000                       0.282000
# 111                  0.268000  0.559000                       0.270000
# 139                  0.295213  0.275399                       0.212187
# 139                  0.155000  0.298000                       0.212000
# 107                  0.578000  0.283000                       0.082000
#
#      Generosity    Year
# 119    0.248340  2015.0
# 75     0.272250  2016.0
# 154    0.280876  2017.0
# 97     0.238000  2018.0
# 111    0.243000  2019.0
# 139    0.187402  2020.0
# 139    0.172000  2021.0
# 107    0.225000  2022.0

# %% [markdown]
# # insights

# %%
a =np.mean(Merged['Happiness Score'][Merged['Year']==2015])

# %%
b = np.mean(Merged['Happiness Score'][Merged['Year']==2016])

# %%
c = np.mean(Merged['Happiness Score'][Merged['Year']==2017])

# %%
d = np.mean(Merged['Happiness Score'][Merged['Year']==2018])

# %%
e = np.mean(Merged['Happiness Score'][Merged['Year']==2019])

# %%
f= np.mean(Merged['Happiness Score'][Merged['Year']==2020])

# %%
g = np.mean(Merged['Happiness Score'][Merged['Year']==2021])

# %%
h = np.mean(Merged['Happiness Score'][Merged['Year']==2022])

# %%
means = [a,b,c,d,e,f,g,h]
t = np.diff(means)
#2015,2016,2017,2018,2019,2020,2021,2022

# %%
np.sum(t)/7
# Out:
# 0.025405880750079973

# %%
def fit(x,y):
    pass
    return(m,b)
def standard_units(x):
    "Convert any array of numbers to standard units."
    return (x - np.average(x))/np.std(x,ddof=1)  

def correlation(x, y):
    x_in_standard_units = standard_units(x)
    y_in_standard_units = standard_units(y)
    if len(x)!=len(y):
        raise ValueError('arrays are of different lengths')
    return sum(x_in_standard_units * y_in_standard_units)/(len(x)-1)

def slope(x, y):
    if len(x)!=len(y):
        raise ValueError('arrays are of different lengths')
    return  correlation(x, y)* np.std(y,ddof=1)/np.std(x,ddof=1)

def intercept(x, y):
    b1 = slope(x, y)
    return np.average(y) - b1 * np.average(x)

def fitted_values(x, y):
    """Return an array of the regressions estimates at all the x values"""
    b1 = slope(x, y)
    b0 = intercept(x, y)
    return b1*x + b0

# %%
a=fitted_values(Merged['Freedom'],Merged['Happiness Score'])
plt.scatter(Merged['Freedom'],Merged['Happiness Score'])
plt.scatter(Merged['Freedom'],a)
correlation(Merged['Freedom'],Merged['Happiness Score'])
# Out:
# 0.5665543160055392

# %%
plt.scatter(Merged['Happiness Score'],Merged['Economy (GDP per Capita)'])

# %%
plt.scatter(Merged['Happiness Score'],Merged['Generosity'])

# %%
plt.scatter(Merged['Happiness Score'],Merged['Trust (Government Corruption)'])

# %%
plt.bar(Merged['Year'],Merged['Happiness Score'])
# Out:
# <BarContainer object of 1229 artists>

# %%
plt.bar(Merged['Region'],Merged['Happiness Score'])
# Out:
# <BarContainer object of 1229 artists>

# %% [markdown]
# # Correlation

# %%
def fit(x,y):
    pass
    return(m,b)
def standard_units(x):
    "Convert any array of numbers to standard units."
    return (x - np.average(x))/np.std(x,ddof=1)  

def correlation(x, y):
    x_in_standard_units = standard_units(x)
    y_in_standard_units = standard_units(y)
    if len(x)!=len(y):
        raise ValueError('arrays are of different lengths')
    return sum(x_in_standard_units * y_in_standard_units)/(len(x)-1)

def slope(x, y):
    if len(x)!=len(y):
        raise ValueError('arrays are of different lengths')
    return  correlation(x, y)* np.std(y,ddof=1)/np.std(x,ddof=1)

def intercept(x, y):
    b1 = slope(x, y)
    return np.average(y) - b1 * np.average(x)

def fitted_values(x, y):
    """Return an array of the regressions estimates at all the x values"""
    b1 = slope(x, y)
    b0 = intercept(x, y)
    return b1*x + b0

# %%
correlation(Merged['Happiness Score'],Merged['Freedom'])
# Out:
# 0.5665543160055392

# %%
correlation(Merged['Happiness Score'],Merged['Economy (GDP per Capita)'])
# Out:
# 0.7424381769077983

# %%
correlation(Merged['Happiness Score'],Merged['Generosity'])
# Out:
# 0.09144014220841956

# %%
correlation(Merged['Happiness Score'],Merged['Trust (Government Corruption)'])
# Out:
# 0.4072410891442601

# %%
correlation(Merged['Happiness Score'],Merged['Health (Life Expectancy)'])
# Out:
# 0.7279035495337519

# %%
correlation(Merged['Happiness Score'],Merged['Family (Social Support)'])
# Out:
# 0.6297714211910058
